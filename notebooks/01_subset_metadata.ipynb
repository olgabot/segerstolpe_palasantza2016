# %%
import os

import pandas as pd

import common

# Assign notebook and folder names
notebook_name = '01_subset_metadata'
figure_folder = os.path.join(common.FIGURE_FOLDER, notebook_name)
data_folder = os.path.join(common.DATA_FOLDER, notebook_name)
print('Figure folder:', figure_folder)
print('Data folder:', data_folder)

# Make the folders
! mkdir -p $figure_folder
! mkdir -p $data_folder
# Out:
# Figure folder: ../figures/01_subset_metadata
# Data folder: ../data/01_subset_metadata

# %% [markdown]
# First read in the table that contains all the metadata. Print the length of the table (to know how many cells we are dealing with) and look at the first 5 rows.

# %%
metadata = pd.read_table("../data/00_original/E-MTAB-5061.sdrf.txt", index_col=0)
print(len(metadata))
metadata.head(5)
# Out:
# 3514
#             Comment[ENA_SAMPLE] Comment[BioSD_SAMPLE]  \
# Source Name
# AZ_A1                ERS1348470          SAMEA4437021
# AZ_A10               ERS1348471          SAMEA4437022
# AZ_A11               ERS1348472          SAMEA4437023
# AZ_A12               ERS1348473          SAMEA4437024
# AZ_A2                ERS1348474          SAMEA4437025
#
#             Characteristics[organism] Characteristics[organism part]  \
# Source Name
# AZ_A1                    Homo sapiens                       pancreas
# AZ_A10                   Homo sapiens                       pancreas
# AZ_A11                   Homo sapiens                       pancreas
# AZ_A12                   Homo sapiens                       pancreas
# AZ_A2                    Homo sapiens                       pancreas
#
#             Characteristics[individual]  \
# Source Name
# AZ_A1                                AZ
# AZ_A10                               AZ
# AZ_A11                               AZ
# AZ_A12                               AZ
# AZ_A2                                AZ
#
#             Characteristics[single cell well quality]  \
# Source Name
# AZ_A1                                low quality cell
# AZ_A10                                             OK
# AZ_A11                                             OK
# AZ_A12                                             OK
# AZ_A2                                              OK
#
#             Characteristics[cell type] Characteristics[disease]  \
# Source Name
# AZ_A1                   not applicable                   normal
# AZ_A10                      delta cell                   normal
# AZ_A11                      alpha cell                   normal
# AZ_A12                      delta cell                   normal
# AZ_A2                       gamma cell                   normal
#
#             Characteristics[sex]  Characteristics[age]  \
# Source Name
# AZ_A1                       male                    43
# AZ_A10                      male                    43
# AZ_A11                      male                    43
# AZ_A12                      male                    43
# AZ_A2                       male                    43
#
#                       ...           Comment[ENA_EXPERIMENT]        Scan Name  \
# Source Name           ...
# AZ_A1                 ...                        ERX1700346   AZ_A1.fastq.gz
# AZ_A10                ...                        ERX1700347  AZ_A10.fastq.gz
# AZ_A11                ...                        ERX1700348  AZ_A11.fastq.gz
# AZ_A12                ...                        ERX1700349  AZ_A12.fastq.gz
# AZ_A2                 ...                        ERX1700350   AZ_A2.fastq.gz
#
#             Comment[SUBMITTED_FILE_NAME]  Comment[ENA_RUN]  \
# Source Name
# AZ_A1                     AZ_A1.fastq.gz        ERR1630013
# AZ_A10                   AZ_A10.fastq.gz        ERR1630014
# AZ_A11                   AZ_A11.fastq.gz        ERR1630015
# AZ_A12                   AZ_A12.fastq.gz        ERR1630016
# AZ_A2                     AZ_A2.fastq.gz        ERR1630017
#
#                                             Comment[FASTQ_URI] Protocol REF.3  \
# Source Name
# AZ_A1        ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/003/...   P-MTAB-51966
# AZ_A10       ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/004/...   P-MTAB-51966
# AZ_A11       ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/005/...   P-MTAB-51966
# AZ_A12       ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/006/...   P-MTAB-51966
# AZ_A2        ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/007/...   P-MTAB-51966
#
#                              Derived Array Data File  \
# Source Name
# AZ_A1        pancreas_refseq_rpkms_counts_3514sc.txt
# AZ_A10       pancreas_refseq_rpkms_counts_3514sc.txt
# AZ_A11       pancreas_refseq_rpkms_counts_3514sc.txt
# AZ_A12       pancreas_refseq_rpkms_counts_3514sc.txt
# AZ_A2        pancreas_refseq_rpkms_counts_3514sc.txt
#
#                        Comment [Derived ArrayExpress FTP file]  \
# Source Name
# AZ_A1        ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AZ_A10       ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AZ_A11       ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AZ_A12       ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AZ_A2        ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#             Factor Value[disease] Factor Value[cell type]
# Source Name
# AZ_A1                      normal          not applicable
# AZ_A10                     normal              delta cell
# AZ_A11                     normal              alpha cell
# AZ_A12                     normal              delta cell
# AZ_A2                      normal              gamma cell
#
# [5 rows x 38 columns]

# %% [markdown]
# We are only going to keep a small number of cells to analyze on our machines locally. Let's define a few cell populations to keep for the analysis.

# %% [markdown]
# I'm going to take a look at the data to see how many cells were collected per patient, per cell type. First, groupby will collect by patient age and cell type. Then I will call a specific column to count (in this case 'Comment[ENA_SAMPLE]') which will give me a count of the number of cells in each age and cell type

# %%
pd.options.display.max_rows=1000

metadata.groupby(by = ['Characteristics[age]','Characteristics[cell type]'])['Comment[ENA_SAMPLE]'].count()
# Out:
# Characteristics[age]  Characteristics[cell type]
# 22                    PSC cell                         6
#                       acinar cell                      3
#                       alpha cell                     136
#                       beta cell                       34
#                       co-expression cell               6
#                       delta cell                       7
#                       ductal cell                      8
#                       endothelial cell                 1
#                       gamma cell                       2
#                       not applicable                 180
# 23                    PSC cell                        10
#                       acinar cell                      3
#                       alpha cell                      92
#                       beta cell                       35
#                       co-expression cell               6
#                       delta cell                      12
#                       ductal cell                     14
#                       endothelial cell                 8
#                       epsilon cell                     3
#                       gamma cell                      31
#                       not applicable                 163
#                       unclassified cell                1
#                       unclassified endocrine cell      5
# 25                    PSC cell                         1
#                       acinar cell                     20
#                       alpha cell                     117
#                       beta cell                       48
#                       co-expression cell               3
#                       delta cell                      21
#                       ductal cell                     19
#                       endothelial cell                 1
#                       epsilon cell                     1
#                       gamma cell                      19
#                       mast cell                        4
#                       not applicable                  83
#                       unclassified endocrine cell     15
# 27                    PSC cell                         3
#                       acinar cell                      2
#                       alpha cell                      44
#                       beta cell                       10
#                       co-expression cell               3
#                       delta cell                      10
#                       ductal cell                     23
#                       endothelial cell                 2
#                       gamma cell                       1
#                       not applicable                 285
# 37                    MHC class II cell                2
#                       PSC cell                        12
#                       acinar cell                     28
#                       alpha cell                     119
#                       beta cell                       14
#                       co-expression cell               5
#                       delta cell                       6
#                       ductal cell                     76
#                       endothelial cell                 1
#                       gamma cell                       8
#                       mast cell                        2
#                       not applicable                 107
#                       unclassified endocrine cell      3
# 43                    MHC class II cell                1
#                       PSC cell                         1
#                       acinar cell                      4
#                       alpha cell                      28
#                       beta cell                       12
#                       co-expression cell               3
#                       delta cell                       7
#                       ductal cell                      4
#                       endothelial cell                 1
#                       gamma cell                       7
#                       not applicable                  23
#                       unclassified endocrine cell      5
# 48                    PSC cell                         2
#                       acinar cell                     80
#                       alpha cell                      26
#                       beta cell                       32
#                       co-expression cell               5
#                       delta cell                       2
#                       ductal cell                     67
#                       epsilon cell                     1
#                       gamma cell                      15
#                       not applicable                 149
#                       unclassified endocrine cell      4
# 52                    MHC class II cell                1
#                       PSC cell                        13
#                       acinar cell                     24
#                       alpha cell                      87
#                       beta cell                       11
#                       co-expression cell               1
#                       delta cell                       5
#                       ductal cell                    125
#                       endothelial cell                 1
#                       gamma cell                      10
#                       not applicable                 100
#                       unclassified endocrine cell      6
# 55                    MHC class II cell                1
#                       PSC cell                         4
#                       acinar cell                     13
#                       alpha cell                      96
#                       beta cell                       64
#                       co-expression cell               6
#                       delta cell                      35
#                       ductal cell                     47
#                       epsilon cell                     1
#                       gamma cell                      34
#                       mast cell                        1
#                       not applicable                  82
# 57                    PSC cell                         2
#                       acinar cell                      8
#                       alpha cell                     141
#                       beta cell                       10
#                       co-expression cell               1
#                       delta cell                       9
#                       ductal cell                      3
#                       endothelial cell                 1
#                       epsilon cell                     1
#                       gamma cell                      70
#                       not applicable                 133
#                       unclassified cell                1
#                       unclassified endocrine cell      3
# Name: Comment[ENA_SAMPLE], dtype: int64

# %% [markdown]
# We are going to focus on the endocrine cells, so I am going to subset the metadata only for endocrine

# %%
cell_types_to_keep = ['alpha cell','beta cell','gamma cell','delta cell',
                      'unclassified endocrine cell','epsilon cell']

# %% [markdown]
# This is a subset of endocrine cells so I am going to call this subset endocrine only. With .loc I am pointing to a COLUMN in medata that is called 'Characteristics[cell type]'. Then I am keeping all the rows that contain a value in that column that is in my list defined above. This cuts it down to 629 cells.

# %%
endocrine_only = metadata.loc[metadata['Characteristics[cell type]'].isin(cell_types_to_keep)]
print(len(endocrine_only))
endocrine_only.head()
# Out:
# 1515
#             Comment[ENA_SAMPLE] Comment[BioSD_SAMPLE]  \
# Source Name
# AZ_A10               ERS1348471          SAMEA4437022
# AZ_A11               ERS1348472          SAMEA4437023
# AZ_A12               ERS1348473          SAMEA4437024
# AZ_A2                ERS1348474          SAMEA4437025
# AZ_A6                ERS1348478          SAMEA4437029
#
#             Characteristics[organism] Characteristics[organism part]  \
# Source Name
# AZ_A10                   Homo sapiens                       pancreas
# AZ_A11                   Homo sapiens                       pancreas
# AZ_A12                   Homo sapiens                       pancreas
# AZ_A2                    Homo sapiens                       pancreas
# AZ_A6                    Homo sapiens                       pancreas
#
#             Characteristics[individual]  \
# Source Name
# AZ_A10                               AZ
# AZ_A11                               AZ
# AZ_A12                               AZ
# AZ_A2                                AZ
# AZ_A6                                AZ
#
#             Characteristics[single cell well quality]  \
# Source Name
# AZ_A10                                             OK
# AZ_A11                                             OK
# AZ_A12                                             OK
# AZ_A2                                              OK
# AZ_A6                                              OK
#
#             Characteristics[cell type] Characteristics[disease]  \
# Source Name
# AZ_A10                      delta cell                   normal
# AZ_A11                      alpha cell                   normal
# AZ_A12                      delta cell                   normal
# AZ_A2                       gamma cell                   normal
# AZ_A6                       alpha cell                   normal
#
#             Characteristics[sex]  Characteristics[age]  \
# Source Name
# AZ_A10                      male                    43
# AZ_A11                      male                    43
# AZ_A12                      male                    43
# AZ_A2                       male                    43
# AZ_A6                       male                    43
#
#                       ...           Comment[ENA_EXPERIMENT]        Scan Name  \
# Source Name           ...
# AZ_A10                ...                        ERX1700347  AZ_A10.fastq.gz
# AZ_A11                ...                        ERX1700348  AZ_A11.fastq.gz
# AZ_A12                ...                        ERX1700349  AZ_A12.fastq.gz
# AZ_A2                 ...                        ERX1700350   AZ_A2.fastq.gz
# AZ_A6                 ...                        ERX1700354   AZ_A6.fastq.gz
#
#             Comment[SUBMITTED_FILE_NAME]  Comment[ENA_RUN]  \
# Source Name
# AZ_A10                   AZ_A10.fastq.gz        ERR1630014
# AZ_A11                   AZ_A11.fastq.gz        ERR1630015
# AZ_A12                   AZ_A12.fastq.gz        ERR1630016
# AZ_A2                     AZ_A2.fastq.gz        ERR1630017
# AZ_A6                     AZ_A6.fastq.gz        ERR1630021
#
#                                             Comment[FASTQ_URI] Protocol REF.3  \
# Source Name
# AZ_A10       ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/004/...   P-MTAB-51966
# AZ_A11       ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/005/...   P-MTAB-51966
# AZ_A12       ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/006/...   P-MTAB-51966
# AZ_A2        ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/007/...   P-MTAB-51966
# AZ_A6        ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/001/...   P-MTAB-51966
#
#                              Derived Array Data File  \
# Source Name
# AZ_A10       pancreas_refseq_rpkms_counts_3514sc.txt
# AZ_A11       pancreas_refseq_rpkms_counts_3514sc.txt
# AZ_A12       pancreas_refseq_rpkms_counts_3514sc.txt
# AZ_A2        pancreas_refseq_rpkms_counts_3514sc.txt
# AZ_A6        pancreas_refseq_rpkms_counts_3514sc.txt
#
#                        Comment [Derived ArrayExpress FTP file]  \
# Source Name
# AZ_A10       ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AZ_A11       ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AZ_A12       ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AZ_A2        ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AZ_A6        ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#             Factor Value[disease] Factor Value[cell type]
# Source Name
# AZ_A10                     normal              delta cell
# AZ_A11                     normal              alpha cell
# AZ_A12                     normal              delta cell
# AZ_A2                      normal              gamma cell
# AZ_A6                      normal              alpha cell
#
# [5 rows x 38 columns]

# %% [markdown]
# That's still too many cells. So let's only keep cells from 6 people, 3 healthy and 3 T2D

# %% [markdown]
# How many cells came from each person in this group? In this data, the unique people are marked with a different age. So I am going to count the number of time each age value appears in the age column with value_counts()
#
# This tells me that 234 endocrine cells were collected from the donor that was 57 years old and so on...

# %%
endocrine_only['Characteristics[age]'].value_counts()
# Out:
# 57    234
# 55    230
# 25    221
# 22    179
# 23    178
# 37    150
# 52    119
# 48     80
# 27     65
# 43     59
# Name: Characteristics[age], dtype: int64

# %% [markdown]
# I am going to pick 6 people to keep.

# %%
ages_to_keep = ['23','22','25','57','52','55']

endocrine_only_6_samples = endocrine_only.loc[endocrine_only['Characteristics[age]'].isin(ages_to_keep)]
print(len(endocrine_only_6_samples))
endocrine_only_6_samples.head()
# Out:
# 1161
#               Comment[ENA_SAMPLE] Comment[BioSD_SAMPLE]  \
# Source Name
# HP1502401_A10          ERS1348567          SAMEA4437118
# HP1502401_A12          ERS1348569          SAMEA4437120
# HP1502401_A15          ERS1348571          SAMEA4437122
# HP1502401_A17          ERS1348573          SAMEA4437124
# HP1502401_A18          ERS1348574          SAMEA4437125
#
#               Characteristics[organism] Characteristics[organism part]  \
# Source Name
# HP1502401_A10              Homo sapiens                       pancreas
# HP1502401_A12              Homo sapiens                       pancreas
# HP1502401_A15              Homo sapiens                       pancreas
# HP1502401_A17              Homo sapiens                       pancreas
# HP1502401_A18              Homo sapiens                       pancreas
#
#               Characteristics[individual]  \
# Source Name
# HP1502401_A10                   HP1502401
# HP1502401_A12                   HP1502401
# HP1502401_A15                   HP1502401
# HP1502401_A17                   HP1502401
# HP1502401_A18                   HP1502401
#
#               Characteristics[single cell well quality]  \
# Source Name
# HP1502401_A10                                        OK
# HP1502401_A12                                        OK
# HP1502401_A15                                        OK
# HP1502401_A17                                        OK
# HP1502401_A18                                        OK
#
#               Characteristics[cell type] Characteristics[disease]  \
# Source Name
# HP1502401_A10                  beta cell                   normal
# HP1502401_A12                 alpha cell                   normal
# HP1502401_A15                 alpha cell                   normal
# HP1502401_A17                 alpha cell                   normal
# HP1502401_A18                 delta cell                   normal
#
#               Characteristics[sex]  Characteristics[age]  \
# Source Name
# HP1502401_A10                 male                    25
# HP1502401_A12                 male                    25
# HP1502401_A15                 male                    25
# HP1502401_A17                 male                    25
# HP1502401_A18                 male                    25
#
#                         ...           Comment[ENA_EXPERIMENT]  \
# Source Name             ...
# HP1502401_A10           ...                        ERX1700443
# HP1502401_A12           ...                        ERX1700445
# HP1502401_A15           ...                        ERX1700447
# HP1502401_A17           ...                        ERX1700449
# HP1502401_A18           ...                        ERX1700450
#
#                             Scan Name Comment[SUBMITTED_FILE_NAME]  \
# Source Name
# HP1502401_A10  HP1502401_A10.fastq.gz       HP1502401_A10.fastq.gz
# HP1502401_A12  HP1502401_A12.fastq.gz       HP1502401_A12.fastq.gz
# HP1502401_A15  HP1502401_A15.fastq.gz       HP1502401_A15.fastq.gz
# HP1502401_A17  HP1502401_A17.fastq.gz       HP1502401_A17.fastq.gz
# HP1502401_A18  HP1502401_A18.fastq.gz       HP1502401_A18.fastq.gz
#
#                Comment[ENA_RUN]  \
# Source Name
# HP1502401_A10        ERR1630110
# HP1502401_A12        ERR1630112
# HP1502401_A15        ERR1630114
# HP1502401_A17        ERR1630116
# HP1502401_A18        ERR1630117
#
#                                               Comment[FASTQ_URI]  \
# Source Name
# HP1502401_A10  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/000/...
# HP1502401_A12  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/002/...
# HP1502401_A15  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/004/...
# HP1502401_A17  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/006/...
# HP1502401_A18  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/007/...
#
#               Protocol REF.3                  Derived Array Data File  \
# Source Name
# HP1502401_A10   P-MTAB-51966  pancreas_refseq_rpkms_counts_3514sc.txt
# HP1502401_A12   P-MTAB-51966  pancreas_refseq_rpkms_counts_3514sc.txt
# HP1502401_A15   P-MTAB-51966  pancreas_refseq_rpkms_counts_3514sc.txt
# HP1502401_A17   P-MTAB-51966  pancreas_refseq_rpkms_counts_3514sc.txt
# HP1502401_A18   P-MTAB-51966  pancreas_refseq_rpkms_counts_3514sc.txt
#
#                          Comment [Derived ArrayExpress FTP file]  \
# Source Name
# HP1502401_A10  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# HP1502401_A12  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# HP1502401_A15  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# HP1502401_A17  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# HP1502401_A18  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#               Factor Value[disease] Factor Value[cell type]
# Source Name
# HP1502401_A10                normal               beta cell
# HP1502401_A12                normal              alpha cell
# HP1502401_A15                normal              alpha cell
# HP1502401_A17                normal              alpha cell
# HP1502401_A18                normal              delta cell
#
# [5 rows x 38 columns]

# %% [markdown]
# That's still too many cells, so I am only going to keep 50 alpha cells per person in addition to all the rest of the enodcrine cells.

# %% [markdown]
# There is a lot going on in this loop. I will break down each step.
#
# I am going to loop over the ages to keep because for each person, I need to grab 50 alpha cells.
#
# The first row grabs all the rows in the dataframe that come from one person.
#
# Then I grab only the rows that are alpha cells.
#
# I define rows_to_keep as the first 50 alpha cells (head(50))
#
# I make a new dataframe to be everything from the old one EXCEPT the alpha cells.
#
# Then I make a new dataframe (df_final) with only 50 alpha rows, plus the dataframe that has no alpha cells.
#
# I print the lengths of each to check that I am really adding 50 for each one.
#
# Then at the end I am saving that dataframe into a list of dataframes that I opened in the beginning (called all_dfs). After the loop finishes, I am merging all of the dataframes back into one with pd.concat(all_dfs) leaving us with a metadata_subset.

# %%
endocrine_only_6_samples.groupby(by=['Characteristics[cell type]','Characteristics[age]'])['Comment[ENA_SAMPLE]'].count()
# Out:
# Characteristics[cell type]   Characteristics[age]
# alpha cell                   22                      136
#                              23                       92
#                              25                      117
#                              52                       87
#                              55                       96
#                              57                      141
# beta cell                    22                       34
#                              23                       35
#                              25                       48
#                              52                       11
#                              55                       64
#                              57                       10
# delta cell                   22                        7
#                              23                       12
#                              25                       21
#                              52                        5
#                              55                       35
#                              57                        9
# epsilon cell                 23                        3
#                              25                        1
#                              55                        1
#                              57                        1
# gamma cell                   22                        2
#                              23                       31
#                              25                       19
#                              52                       10
#                              55                       34
#                              57                       70
# unclassified endocrine cell  23                        5
#                              25                       15
#                              52                        6
#                              57                        3
# Name: Comment[ENA_SAMPLE], dtype: int64

# %%
all_dfs = []

for i in ages_to_keep:
    print("age = "+str(i))
    df = endocrine_only_6_samples.loc[endocrine_only_6_samples['Characteristics[age]'] == int(i)]
    alpha_rows = df.loc[df['Characteristics[cell type]'] == 'alpha cell']
    alpha_rows_to_keep = alpha_rows.head(50)
    df_new = df.loc[df['Characteristics[cell type]'] != 'alpha cell']
    print(len(df_new))
    df_final = pd.concat([df_new, alpha_rows_to_keep])
    print(len(df_final))
    all_dfs.append(df_final)

metadata_subset = pd.concat(all_dfs)
# Out:
# age = 23
# 86
# 136
# age = 22
# 43
# 93
# age = 25
# 104
# 154
# age = 57
# 93
# 143
# age = 52
# 32
# 82
# age = 55
# 134
# 184

# %%
print(len(metadata_subset))
metadata_subset.head()
# Out:
# 792
#               Comment[ENA_SAMPLE] Comment[BioSD_SAMPLE]  \
# Source Name
# HP1504901_A10          ERS1349302          SAMEA4437853
# HP1504901_A16          ERS1349308          SAMEA4437859
# HP1504901_A21          ERS1349314          SAMEA4437865
# HP1504901_A3           ERS1349318          SAMEA4437869
# HP1504901_A5           ERS1349320          SAMEA4437871
#
#               Characteristics[organism] Characteristics[organism part]  \
# Source Name
# HP1504901_A10              Homo sapiens                       pancreas
# HP1504901_A16              Homo sapiens                       pancreas
# HP1504901_A21              Homo sapiens                       pancreas
# HP1504901_A3               Homo sapiens                       pancreas
# HP1504901_A5               Homo sapiens                       pancreas
#
#               Characteristics[individual]  \
# Source Name
# HP1504901_A10                   HP1504901
# HP1504901_A16                   HP1504901
# HP1504901_A21                   HP1504901
# HP1504901_A3                    HP1504901
# HP1504901_A5                    HP1504901
#
#               Characteristics[single cell well quality]  \
# Source Name
# HP1504901_A10                                        OK
# HP1504901_A16                                        OK
# HP1504901_A21                                        OK
# HP1504901_A3                                         OK
# HP1504901_A5                                         OK
#
#               Characteristics[cell type] Characteristics[disease]  \
# Source Name
# HP1504901_A10                 delta cell                   normal
# HP1504901_A16                  beta cell                   normal
# HP1504901_A21                 delta cell                   normal
# HP1504901_A3                   beta cell                   normal
# HP1504901_A5                  gamma cell                   normal
#
#               Characteristics[sex]  Characteristics[age]  \
# Source Name
# HP1504901_A10                 male                    23
# HP1504901_A16                 male                    23
# HP1504901_A21                 male                    23
# HP1504901_A3                  male                    23
# HP1504901_A5                  male                    23
#
#                         ...           Comment[ENA_EXPERIMENT]  \
# Source Name             ...
# HP1504901_A10           ...                        ERX1701178
# HP1504901_A16           ...                        ERX1701184
# HP1504901_A21           ...                        ERX1701190
# HP1504901_A3            ...                        ERX1701194
# HP1504901_A5            ...                        ERX1701196
#
#                             Scan Name Comment[SUBMITTED_FILE_NAME]  \
# Source Name
# HP1504901_A10  HP1504901_A10.fastq.gz       HP1504901_A10.fastq.gz
# HP1504901_A16  HP1504901_A16.fastq.gz       HP1504901_A16.fastq.gz
# HP1504901_A21  HP1504901_A21.fastq.gz       HP1504901_A21.fastq.gz
# HP1504901_A3    HP1504901_A3.fastq.gz        HP1504901_A3.fastq.gz
# HP1504901_A5    HP1504901_A5.fastq.gz        HP1504901_A5.fastq.gz
#
#                Comment[ENA_RUN]  \
# Source Name
# HP1504901_A10        ERR1630845
# HP1504901_A16        ERR1630851
# HP1504901_A21        ERR1630857
# HP1504901_A3         ERR1630861
# HP1504901_A5         ERR1630863
#
#                                               Comment[FASTQ_URI]  \
# Source Name
# HP1504901_A10  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/005/...
# HP1504901_A16  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/001/...
# HP1504901_A21  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/007/...
# HP1504901_A3   ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/001/...
# HP1504901_A5   ftp://ftp.sra.ebi.ac.uk/vol1/fastq/ERR163/003/...
#
#               Protocol REF.3                  Derived Array Data File  \
# Source Name
# HP1504901_A10   P-MTAB-51966  pancreas_refseq_rpkms_counts_3514sc.txt
# HP1504901_A16   P-MTAB-51966  pancreas_refseq_rpkms_counts_3514sc.txt
# HP1504901_A21   P-MTAB-51966  pancreas_refseq_rpkms_counts_3514sc.txt
# HP1504901_A3    P-MTAB-51966  pancreas_refseq_rpkms_counts_3514sc.txt
# HP1504901_A5    P-MTAB-51966  pancreas_refseq_rpkms_counts_3514sc.txt
#
#                          Comment [Derived ArrayExpress FTP file]  \
# Source Name
# HP1504901_A10  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# HP1504901_A16  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# HP1504901_A21  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# HP1504901_A3   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# HP1504901_A5   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#               Factor Value[disease] Factor Value[cell type]
# Source Name
# HP1504901_A10                normal              delta cell
# HP1504901_A16                normal               beta cell
# HP1504901_A21                normal              delta cell
# HP1504901_A3                 normal               beta cell
# HP1504901_A5                 normal              gamma cell
#
# [5 rows x 38 columns]

# %% [markdown]
# 792 cells! Great, we're happy with that number, so let's save the subset file as a csv)

# %%
metadata_subset.to_csv(data_folder+"/metadata_subset_792_cells.txt", sep="\t", encoding='utf-8')
